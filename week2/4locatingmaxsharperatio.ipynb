# %% [markdown]
# # Finding the max sharpe ratio

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import edhec_risk_kit_all as erk
ind=erk.get_ind_returns()
er=erk.annualize_rets(ind["1996":"2000"],12)
cov=ind["1996":"2000"].cov()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize

# %%
ax=erk.plot_ef(20,er,cov,show_cml=True,riskfree_rate=0.1)

rf=0.1
w_msr=erk.msr(rf,er,cov)
r_msr=erk.portfolio_return(w_msr,er)
vol_msr=erk.portfolio_vol(w_msr,cov)
# add cml
cml_x=[0,vol_msr]
cml_y=[rf,r_msr]
#ax.plot(cml_x,cml_y,color="green",marker="o",linestyle="dashed")

# %%
w_msr,r_msr,vol_msr
# Out:
# (array([3.66358350e-15, 0.00000000e+00, 1.92072532e-15, 2.96834546e-15,
#         5.90393422e-16, 0.00000000e+00, 0.00000000e+00, 4.55961475e-01,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         8.16661498e-16, 2.33810854e-01, 0.00000000e+00, 3.49206138e-15,
#         0.00000000e+00, 1.38704169e-01, 1.98080821e-15, 8.94091633e-02,
#         1.15596740e-16, 0.00000000e+00, 1.55177020e-02, 0.00000000e+00,
#         0.00000000e+00, 1.71021610e-15, 6.65966365e-02, 0.00000000e+00,
#         6.16592511e-16, 3.28275516e-16]),
#  0.2647394847362751,
#  0.045719732826051)

# %%
erk.plot_ef(40,er,cov,show_cml=True, riskfree_rate=0.1)
