# %% [markdown]
# # Random Walk Generation

# %% [markdown]
# ## $$ \frac{S_{t+dt}-S_t}{S_t} = \mu dt + \sigma\sqrt{dt}\xi_t $$

# %%
import pandas as pd
import numpy as mp
import edhec_risk_kit_all as erk

# %%
p=erk.gbm(  n_years=10,
    n_scenarios=1000,
    mu=0.07,
    sigma=0.15,
    steps_per_year=12,
    s_0=100.0,
    prices=True)

# %%
p
# Out:
#             0           1           2           3           4           5    \
# 0    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1     99.557055  101.253188  101.482606   94.906506  100.906294   94.641682
# 2     98.326354   96.381890  102.208524   98.550169  109.321761   97.791030
# 3     99.109518   99.013552  107.348113  102.708444  107.305155  100.423883
# 4    103.675318   95.445249  103.671422   97.511517  108.061046  104.695286
# ..          ...         ...         ...         ...         ...         ...
# 116  194.927508  261.041280  239.840782  265.937730  294.943855  140.276605
# 117  188.793148  276.097509  248.947797  262.719032  281.939407  140.479536
# 118  184.070129  280.653010  244.461949  275.382527  277.221504  126.540671
# 119  185.847488  289.803623  236.429781  301.499644  273.708010  121.880678
# 120  190.032962  282.668165  233.116705  307.892698  251.076133  117.620253
#
# ...

# %%
p.head()
# Out:
#           0           1           2           3           4           5    \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   99.557055  101.253188  101.482606   94.906506  100.906294   94.641682
# 2   98.326354   96.381890  102.208524   98.550169  109.321761   97.791030
# 3   99.109518   99.013552  107.348113  102.708444  107.305155  100.423883
# 4  103.675318   95.445249  103.671422   97.511517  108.061046  104.695286
#
#           6           7           8           9    ...         990  \
# 0  100.000000  100.000000  100.000000  100.000000  ...  100.000000
# 1   93.997094   98.006096   95.940926  106.693669  ...  102.007566
# 2   98.760176   95.308143   98.824976  109.755795  ...  110.038809
# 3  100.207616   90.028515   91.306571  108.085167  ...  114.914423
# 4   97.419815   94.479868   88.037960  112.802448  ...  125.340460
#
#           991         992         993         994         995         996  \
# ...

# %%
p.plot(legend=False)
# Out:
# <AxesSubplot:>

# %%
# %timeit erk.gbm(n_years=10,n_scenarios=1000,mu=0.07,sigma=0.15)
# Out:
# 2.84 ms ± 15.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
